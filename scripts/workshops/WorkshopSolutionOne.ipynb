# %% [markdown]
# <a href="https://colab.research.google.com/github/johnreyes96/artificial-intelligence/blob/master/src/main/python/workshops/WorkshopSolutionOne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.1

# %%
import numpy as np
import matplotlib.pyplot as plt

w = np.array([3, -4])
b = 2

x2 = np.array([0, 1])
x1 = -(w[1]*x2/w[0])-(b/w[0])
print(x1)

fig, ax = plt.subplots()

ax.plot(x2, x1, linewidth=2.0)
ax.scatter(x=np.array([0.2, 0.6]), y=np.array([0.4, -0.4]), c=['yellow','red'])
plt.show()
# Out:
# [-0.66666667  0.66666667]

# %% [markdown]
# 1.2

# %%
import numpy as np
import matplotlib.pyplot as plt

w = np.array([-1, 1])
b = -1

x2 = np.array([0, 1])
x1 = -(w[1]*x2/w[0])-(b/w[0])
print(x1)

fig, ax = plt.subplots()

ax.plot(x2, x1, linewidth=2.0)
ax.scatter(x=np.array([0.2, 0.8]), y=np.array([-0.2, -0.8]), c=['yellow','red'])
plt.show()
# Out:
# [-1.  0.]

# %% [markdown]
# 1.3

# %%
import numpy as np
import matplotlib.pyplot as plt

w = np.array([2, -1])
b = 0

x2 = np.array([0, 1])
x1 = -(w[1]*x2/w[0])-(b/w[0])
print(x1)

fig, ax = plt.subplots()

ax.plot(x2, x1, linewidth=2.0)
ax.scatter(x=np.array([0.2, 0.8]), y=np.array([0.4, -0.05]), c=['yellow','red'])
plt.show()
# Out:
# [-0.   0.5]

# %% [markdown]
# 1.4

# %%
import numpy as np
import matplotlib.pyplot as plt

w = np.array([0, -2])
b = -3

x2 = np.array([0, 1])
x1 = -(w[1]*x2/w[0])-(b/w[0])
print(x1)

fig, ax = plt.subplots()

ax.plot(x2, x1, linewidth=2.0)
ax.scatter(x=np.array([0.2, 0.8]), y=np.array([-0.2, -0.8]), c=['yellow','red'])
plt.show()
# Out:
# [nan inf]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in long_scalars
